# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Observations
# - The temperatures reach a peak at 0deg Lat and are lowest at the higest positive latitudes and highest negative latitudes
# - The average humidity is highest in regions between Lat -20 to Lat 0
# - Cloud cover and wind velocities do not have an obvious correlation to lattitude
# - These observations are fairly incomplete around the lowest lattitudes due to an apparent undersampling of weather data

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %%
# view the list of cities to QC
#cities

# %%
# weather API definition. Define the URL for use throughout the remainder of code
url = "http://api.openweathermap.org/data/2.5/weather"

# %%
#Get a Look at whats in the data in order to format the subsequent loops and functions
city_test = {"appid": "5865551bfdc2ede032ee45ed103bf041","q": "Austin"}
response = requests.get(url, params = city_test)
response.json()
# Out:
# {'coord': {'lon': -97.74, 'lat': 30.27},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 294.51,
#   'feels_like': 291.62,
#   'temp_min': 293.15,
#   'temp_max': 296.15,
#   'pressure': 1019,
#   'humidity': 35},
#  'visibility': 16093,
#  'wind': {'speed': 2.6, 'deg': 160},
#  'clouds': {'all': 1},
#  'dt': 1578353243,
#  'sys': {'type': 1,
#   'id': 3344,
#   'country': 'US',
#   'sunrise': 1578317292,
#   'sunset': 1578354281},
#  'timezone': -21600,
#  'id': 4671654,
#  'name': 'Austin',
#  'cod': 200}

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
def city_func(cityname):
    all_cities = {"appid": "5865551bfdc2ede032ee45ed103bf041","q": cityname,"units":"metric"}
    json_data = requests.get(url, params=all_cities).json()
    name = json_data.get("name")
    temp = json_data.get('main').get('temp')
    humid = json_data.get('main').get('humidity')
    clouds = json_data.get('clouds').get('all')
    wind = json_data.get('wind').get('speed')
    lat = json_data.get('coord').get('lat')
    long = json_data.get('coord').get('lon')

    return { "City" : name, "temp": temp,"Lat": lat,"Long": long,"humidity": humid,"Cloud Cover": clouds,"Wind Speed": wind}

# we will create a list for the extracted city information. As the for loop loops through the city names from 
# cities it will match city name with name from weather api

# count the api calls and define empty list to store city information
city_data_ls = []
z = 1

# this loop will loop through the city data. It will run through the city names in the cities list 
# then pass that city name through the function defined above at whch point the try except loop will pass if the names match or print wrong city if they dont
# the function will collect all the data define above for each passing city then store it in the final dataframe for plotting

for city in cities:
    print('city # ' + str(z) + ' ' + str((len(cities))) + ' ' + city)
    z = z + 1
    
    try:
        city_data_ls.append(city_func(city))
    except:
        print('wrong city')
        
#print(city_data_ls)
# Take data and place into dataframe and set our index to the name of the City
final_DF = pd.DataFrame(city_data_ls).set_index('City')
# Out:
# city # 1 640 labrea
# wrong city
# city # 2 640 pedernales
# city # 3 640 kapaa
# city # 4 640 macenta
# city # 5 640 enugu
# city # 6 640 sterling
# city # 7 640 sola
# city # 8 640 sarangani
# city # 9 640 bluff
# city # 10 640 belushya guba
# wrong city
# city # 11 640 pospelikha
# city # 12 640 vila velha
# city # 13 640 samusu
# wrong city
# city # 14 640 shingu
# city # 15 640 rikitea
# city # 16 640 qaanaaq
# city # 17 640 biak
# city # 18 640 torbay
# city # 19 640 saint george
# city # 20 640 taolanaro
# wrong city
# city # 21 640 san quintin
# city # 22 640 mahebourg
# city # 23 640 hilo
# city # 24 640 katsuura
# city # 25 640 narsaq
# city # 26 640 buraydah
# city # 27 640 ferkessedougou
# city # 28 640 chuy
# city # 29 640 east london
# city # 30 640 umzimvubu
# wrong city
# city # 31 640 saint-philippe
# city # 32 640 hithadhoo
# city # 33 640 trincomalee
# city # 34 640 port alfred
# city # 35 640 scarborough
# city # 36 640 mataura
# city # 37 640 leningradskiy
# city # 38 640 nara
# city # 39 640 diu
# city # 40 640 denia
# city # 41 640 okitipupa
# city # 42 640 hobart
# city # 43 640 arraial do cabo
# city # 44 640 tongren
# city # 45 640 soligalich
# city # 46 640 tasiilaq
# city # 47 640 portland
# city # 48 640 padang
# city # 49 640 petropavlovsk-kamchatskiy
# city # 50 640 vaini
# city # 51 640 shahrud
# city # 52 640 busselton
# city # 53 640 killybegs
# city # 54 640 mount isa
# city # 55 640 ushuaia
# city # 56 640 tarata
# city # 57 640 cidreira
# city # 58 640 victoria
# city # 59 640 port elizabeth
# city # 60 640 natal
# city # 61 640 butaritari
# city # 62 640 kodinsk
# city # 63 640 atuona
# city # 64 640 shizunai
# city # 65 640 saleaula
# wrong city
# city # 66 640 klaksvik
# city # 67 640 rafaela
# city # 68 640 luangwa
# city # 69 640 tiksi
# city # 70 640 oranjemund
# city # 71 640 hermanus
# city # 72 640 hay river
# city # 73 640 nikolskoye
# city # 74 640 albany
# city # 75 640 vila
# city # 76 640 lompoc
# city # 77 640 san andres
# city # 78 640 clyde river
# city # 79 640 jamestown
# city # 80 640 thompson
# city # 81 640 kaitangata
# city # 82 640 grindavik
# city # 83 640 victor harbor
# city # 84 640 sumbe
# city # 85 640 stoyba
# wrong city
# city # 86 640 iqaluit
# city # 87 640 caravelas
# city # 88 640 wamba
# city # 89 640 new norfolk
# city # 90 640 puerto del rosario
# city # 91 640 kamenskoye
# wrong city
# city # 92 640 geraldton
# city # 93 640 la cruz
# city # 94 640 dikson
# city # 95 640 berlevag
# city # 96 640 upington
# city # 97 640 cape town
# city # 98 640 acapulco
# city # 99 640 barrow
# city # 100 640 muroto
# city # 101 640 camacha
# city # 102 640 rorvik
# city # 103 640 bengkulu
# wrong city
# city # 104 640 pemangkat
# wrong city
# city # 105 640 lavrentiya
# city # 106 640 batagay-alyta
# city # 107 640 gagnoa
# city # 108 640 beringovskiy
# city # 109 640 punta arenas
# city # 110 640 puerto escondido
# city # 111 640 mar del plata
# city # 112 640 avarua
# city # 113 640 nerchinskiy zavod
# city # 114 640 luderitz
# city # 115 640 barentsburg
# wrong city
# city # 116 640 cabra
# city # 117 640 sioux lookout
# city # 118 640 churapcha
# city # 119 640 vaitape
# city # 120 640 waipawa
# city # 121 640 bambous virieux
# city # 122 640 castro
# city # 123 640 xining
# city # 124 640 pran buri
# city # 125 640 upernavik
# city # 126 640 puerto ayora
# city # 127 640 san vicente
# city # 128 640 grimari
# wrong city
# city # 129 640 khatanga
# city # 130 640 murray bridge
# city # 131 640 waynesville
# city # 132 640 santa maria
# city # 133 640 provideniya
# city # 134 640 langham
# city # 135 640 hami
# city # 136 640 zavetnoye
# city # 137 640 meadow lake
# city # 138 640 longyearbyen
# city # 139 640 nantucket
# city # 140 640 bredasdorp
# city # 141 640 kolokani
# city # 142 640 naze
# city # 143 640 nizhniy odes
# city # 144 640 porto walter
# city # 145 640 kendari
# city # 146 640 tuktoyaktuk
# city # 147 640 krasnoselkup
# wrong city
# city # 148 640 ariano irpino
# city # 149 640 ancud
# city # 150 640 feijo
# city # 151 640 tullahoma
# city # 152 640 santiago del estero
# city # 153 640 la palma
# city # 154 640 roxas
# city # 155 640 chepareria
# city # 156 640 lolua
# wrong city
# city # 157 640 west wendover
# city # 158 640 great yarmouth
# city # 159 640 whitecourt
# city # 160 640 sinjah
# wrong city
# city # 161 640 golden
# city # 162 640 coihaique
# city # 163 640 champerico
# city # 164 640 lincoln
# city # 165 640 kamenka
# city # 166 640 lons-le-saunier
# city # 167 640 guerrero negro
# city # 168 640 mehamn
# city # 169 640 kavaratti
# city # 170 640 ambilobe
# city # 171 640 cherskiy
# city # 172 640 asyut
# city # 173 640 avera
# city # 174 640 ilulissat
# city # 175 640 chokurdakh
# city # 176 640 saskylakh
# city # 177 640 westport
# city # 178 640 ribeira grande
# city # 179 640 hunterville
# city # 180 640 scottsbluff
# city # 181 640 sorong
# city # 182 640 ketchikan
# city # 183 640 nyuksenitsa
# city # 184 640 meyungs
# wrong city
# city # 185 640 nemuro
# city # 186 640 aykhal
# city # 187 640 angoche
# city # 188 640 isangel
# city # 189 640 kodiak
# city # 190 640 ukiah
# city # 191 640 port hedland
# city # 192 640 fare
# city # 193 640 khasan
# city # 194 640 touros
# city # 195 640 ponta do sol
# city # 196 640 rock springs
# city # 197 640 bundaberg
# city # 198 640 matagami
# city # 199 640 mount gambier
# city # 200 640 saint-augustin
# city # 201 640 purpe
# city # 202 640 volkhovskiy
# city # 203 640 himora
# wrong city
# city # 204 640 raga
# wrong city
# city # 205 640 halalo
# wrong city
# city # 206 640 saldanha
# city # 207 640 bolungarvik
# wrong city
# city # 208 640 russkiy kameshkir
# city # 209 640 lagoa
# city # 210 640 kaduy
# city # 211 640 paamiut
# city # 212 640 pevek
# city # 213 640 ponta delgada
# city # 214 640 biltine
# city # 215 640 talnakh
# city # 216 640 itoman
# city # 217 640 emerald
# city # 218 640 shiyan
# city # 219 640 oum hadjer
# city # 220 640 atar
# city # 221 640 sorland
# city # 222 640 abbeville
# city # 223 640 gazni
# wrong city
# city # 224 640 asfi
# wrong city
# city # 225 640 beloha
# city # 226 640 ferme-neuve
# city # 227 640 los llanos de aridane
# city # 228 640 pafos
# wrong city
# city # 229 640 ugoofaaru
# city # 230 640 broome
# city # 231 640 port hardy
# city # 232 640 kedougou
# city # 233 640 lakatoro
# city # 234 640 micheweni
# city # 235 640 port blair
# city # 236 640 alofi
# city # 237 640 daru
# city # 238 640 humaita
# city # 239 640 sao joao da barra
# city # 240 640 gemona
# wrong city
# city # 241 640 dahuk
# wrong city
# city # 242 640 olinda
# city # 243 640 illoqqortoormiut
# wrong city
# city # 244 640 pashiya
# city # 245 640 mendahara
# wrong city
# city # 246 640 yulara
# city # 247 640 esperance
# city # 248 640 saint-louis
# city # 249 640 gigmoto
# city # 250 640 georgetown
# city # 251 640 yellowknife
# city # 252 640 hanyang
# city # 253 640 tual
# city # 254 640 norman wells
# city # 255 640 gondal
# city # 256 640 attawapiskat
# wrong city
# city # 257 640 presidencia roque saenz pena
# city # 258 640 eskil
# city # 259 640 salalah
# city # 260 640 souillac
# city # 261 640 zhezkazgan
# city # 262 640 malatya
# city # 263 640 lebu
# city # 264 640 zolotinka
# wrong city
# city # 265 640 airai
# city # 266 640 ati
# city # 267 640 half moon bay
# city # 268 640 dinghai
# city # 269 640 orsha
# city # 270 640 ode
# city # 271 640 iraray
# city # 272 640 along
# city # 273 640 tiarei
# city # 274 640 karachi
# city # 275 640 pascagoula
# city # 276 640 gra liyia
# city # 277 640 lovozero
# city # 278 640 sentyabrskiy
# wrong city
# city # 279 640 aporawan
# wrong city
# city # 280 640 sechura
# city # 281 640 hamilton
# city # 282 640 sistranda
# city # 283 640 male
# city # 284 640 qinhuangdao
# city # 285 640 kazalinsk
# wrong city
# city # 286 640 meulaboh
# city # 287 640 kulhudhuffushi
# city # 288 640 solnechnyy
# city # 289 640 houston
# city # 290 640 bon accord
# city # 291 640 fairbanks
# city # 292 640 nishihara
# city # 293 640 vaitupu
# wrong city
# city # 294 640 severo-kurilsk
# city # 295 640 obera
# city # 296 640 pangody
# city # 297 640 saint anthony
# city # 298 640 sidi ali
# city # 299 640 kamaishi
# city # 300 640 artyk
# wrong city
# city # 301 640 grand river south east
# wrong city
# city # 302 640 rio cuarto
# city # 303 640 bereda
# city # 304 640 itaqui
# city # 305 640 vostok
# city # 306 640 tabou
# city # 307 640 belle glade
# city # 308 640 henties bay
# city # 309 640 bilibino
# city # 310 640 la plata
# city # 311 640 lianyuan
# city # 312 640 veraval
# city # 313 640 mocambique
# wrong city
# city # 314 640 muros
# city # 315 640 namibe
# city # 316 640 nha trang
# city # 317 640 formoso do araguaia
# wrong city
# city # 318 640 nanortalik
# city # 319 640 otavi
# city # 320 640 amderma
# wrong city
# city # 321 640 kalmunai
# city # 322 640 hofn
# city # 323 640 tahara
# city # 324 640 tucuman
# city # 325 640 darhan
# city # 326 640 fuerte olimpo
# city # 327 640 dalmatovo
# city # 328 640 roald
# city # 329 640 diego de almagro
# city # 330 640 bianzhuang
# city # 331 640 swellendam
# city # 332 640 university park
# city # 333 640 hendersonville
# city # 334 640 suntar
# city # 335 640 adrar
# city # 336 640 inhambane
# city # 337 640 rio gallegos
# city # 338 640 anadyr
# city # 339 640 ambodifototra
# wrong city
# city # 340 640 bambanglipuro
# city # 341 640 fortuna
# city # 342 640 buqayq
# wrong city
# city # 343 640 port lincoln
# city # 344 640 richards bay
# city # 345 640 huarmey
# city # 346 640 deputatskiy
# city # 347 640 wajima
# city # 348 640 tonj
# wrong city
# city # 349 640 marinette
# city # 350 640 yarmouth
# city # 351 640 wilmington island
# city # 352 640 ciras
# wrong city
# city # 353 640 maragogi
# city # 354 640 mayo
# city # 355 640 bubaque
# city # 356 640 hsichih
# wrong city
# city # 357 640 manicore
# city # 358 640 vao
# city # 359 640 vuktyl
# city # 360 640 lasa
# city # 361 640 thyboron
# city # 362 640 havre-saint-pierre
# city # 363 640 the valley
# city # 364 640 swan hill
# city # 365 640 asmara
# city # 366 640 sitka
# city # 367 640 beatrice
# city # 368 640 dumas
# city # 369 640 manresa
# city # 370 640 lucea
# city # 371 640 elizabeth city
# city # 372 640 mys shmidta
# wrong city
# city # 373 640 abyek
# city # 374 640 saint-joseph
# city # 375 640 sal rei
# city # 376 640 sangueya
# city # 377 640 asau
# wrong city
# city # 378 640 san pedro
# city # 379 640 saharanpur
# city # 380 640 carlsbad
# city # 381 640 cabinda
# city # 382 640 san patricio
# city # 383 640 ulaanbaatar
# city # 384 640 raudeberg
# city # 385 640 sao filipe
# city # 386 640 manadhoo
# city # 387 640 tuatapere
# city # 388 640 aljezur
# city # 389 640 sarai naurang
# city # 390 640 phrai bung
# wrong city
# city # 391 640 kutum
# city # 392 640 ligayan
# city # 393 640 badou
# city # 394 640 santa lucia
# city # 395 640 bulgan
# city # 396 640 gat
# city # 397 640 chapais
# city # 398 640 christchurch
# city # 399 640 vanavara
# city # 400 640 kenai
# city # 401 640 clonakilty
# city # 402 640 montepuez
# city # 403 640 khani
# city # 404 640 lebanon
# city # 405 640 taltal
# city # 406 640 semporna
# city # 407 640 paciran
# city # 408 640 cabo san lucas
# city # 409 640 moba
# city # 410 640 flinders
# city # 411 640 palana
# city # 412 640 dorado
# city # 413 640 bethel
# city # 414 640 lokosovo
# city # 415 640 vardo
# city # 416 640 seoul
# city # 417 640 faanui
# city # 418 640 betafo
# city # 419 640 coquimbo
# city # 420 640 ust-kamchatsk
# wrong city
# city # 421 640 goundam
# city # 422 640 soller
# city # 423 640 dogondoutchi
# city # 424 640 boo
# city # 425 640 karratha
# city # 426 640 hervey bay
# city # 427 640 amapa
# city # 428 640 namatanai
# city # 429 640 dingle
# city # 430 640 dabhol
# city # 431 640 poli
# city # 432 640 tsihombe
# wrong city
# city # 433 640 kaeo
# city # 434 640 conceicao do araguaia
# city # 435 640 neuquen
# city # 436 640 vallenar
# city # 437 640 filadelfia
# city # 438 640 alice springs
# city # 439 640 bonthe
# city # 440 640 praia da vitoria
# city # 441 640 belmonte
# city # 442 640 kruisfontein
# city # 443 640 codrington
# city # 444 640 nouadhibou
# city # 445 640 maniitsoq
# city # 446 640 sur
# city # 447 640 port augusta
# city # 448 640 salitral
# city # 449 640 margate
# city # 450 640 aklavik
# city # 451 640 louisbourg
# wrong city
# city # 452 640 kaka
# city # 453 640 vanimo
# city # 454 640 surskoye
# city # 455 640 sabha
# city # 456 640 mogadishu
# city # 457 640 dabat
# city # 458 640 kuala krai
# wrong city
# city # 459 640 manzil salim
# city # 460 640 werda
# city # 461 640 nuevo progreso
# city # 462 640 payo
# city # 463 640 wanaka
# city # 464 640 hearst
# city # 465 640 vestmannaeyjar
# city # 466 640 bati
# city # 467 640 ahipara
# city # 468 640 amga
# city # 469 640 robe
# city # 470 640 hobyo
# city # 471 640 saint-paul
# city # 472 640 chumikan
# city # 473 640 umm kaddadah
# city # 474 640 diapaga
# city # 475 640 kieta
# city # 476 640 pundaguitan
# city # 477 640 lipari
# city # 478 640 krasnyy tekstilshchik
# wrong city
# city # 479 640 sovetskiy
# city # 480 640 balkanabat
# city # 481 640 konevo
# city # 482 640 sendafa
# city # 483 640 saint-francois
# city # 484 640 cocachacra
# city # 485 640 samana
# city # 486 640 faya
# city # 487 640 comodoro rivadavia
# city # 488 640 belle fourche
# city # 489 640 piacabucu
# city # 490 640 salamiyah
# city # 491 640 key west
# city # 492 640 kathu
# city # 493 640 normandin
# city # 494 640 zapodeni
# city # 495 640 coahuayana
# city # 496 640 sumbawa
# wrong city
# city # 497 640 nizhneyansk
# wrong city
# city # 498 640 anito
# city # 499 640 bahia de caraquez
# city # 500 640 carnarvon
# city # 501 640 pingliang
# city # 502 640 tessalit
# city # 503 640 baiyin
# city # 504 640 shache
# city # 505 640 amahai
# city # 506 640 surt
# city # 507 640 pacific grove
# city # 508 640 bayir
# city # 509 640 mullaitivu
# wrong city
# city # 510 640 igarka
# city # 511 640 akdepe
# city # 512 640 mushie
# city # 513 640 sayyan
# city # 514 640 selma
# city # 515 640 ribnica
# city # 516 640 marienburg
# city # 517 640 bikin
# city # 518 640 juan lacaze
# city # 519 640 kem
# city # 520 640 andenes
# wrong city
# city # 521 640 altagracia de orituco
# city # 522 640 tabiauea
# wrong city
# city # 523 640 york
# city # 524 640 methven
# city # 525 640 goderich
# city # 526 640 tapel
# city # 527 640 ayan
# city # 528 640 necochea
# city # 529 640 ulladulla
# city # 530 640 las palmas
# city # 531 640 sobolevo
# city # 532 640 lalpur
# city # 533 640 santa cruz
# city # 534 640 havelock
# city # 535 640 buin
# city # 536 640 sanandaj
# city # 537 640 komsomolskiy
# city # 538 640 bathsheba
# city # 539 640 dharchula
# city # 540 640 mangai
# city # 541 640 bure
# city # 542 640 yerbogachen
# city # 543 640 aflu
# wrong city
# city # 544 640 baruun-urt
# city # 545 640 machico
# city # 546 640 vila franca do campo
# city # 547 640 artyom
# city # 548 640 jashpurnagar
# city # 549 640 coswig
# city # 550 640 gamba
# city # 551 640 tambovka
# city # 552 640 severomuysk
# city # 553 640 prokopyevsk
# city # 554 640 ucar
# city # 555 640 kahului
# city # 556 640 stornoway
# wrong city
# city # 557 640 nyurba
# city # 558 640 umea
# city # 559 640 broken hill
# city # 560 640 utiroa
# wrong city
# city # 561 640 mahadday weyne
# wrong city
# city # 562 640 tereze
# city # 563 640 hasaki
# city # 564 640 verkh-usugli
# city # 565 640 hammerfest
# city # 566 640 lisakovsk
# city # 567 640 eau claire
# city # 568 640 ikungi
# city # 569 640 sikeston
# city # 570 640 chengde
# city # 571 640 barcelos
# city # 572 640 irece
# city # 573 640 portree
# city # 574 640 san juan
# city # 575 640 itarema
# city # 576 640 panzhihua
# city # 577 640 ismailia
# city # 578 640 olafsvik
# wrong city
# city # 579 640 altay
# city # 580 640 kavieng
# city # 581 640 marathon
# city # 582 640 udachnyy
# city # 583 640 jiutai
# city # 584 640 havoysund
# city # 585 640 kiunga
# city # 586 640 palmeiras de goias
# city # 587 640 palabuhanratu
# wrong city
# city # 588 640 bosaso
# city # 589 640 sault sainte marie
# city # 590 640 moose factory
# city # 591 640 ussuriysk
# city # 592 640 belyy yar
# city # 593 640 puerto penasco
# city # 594 640 kawalu
# city # 595 640 chiang rai
# city # 596 640 taoudenni
# city # 597 640 constitucion
# city # 598 640 matay
# city # 599 640 progreso
# city # 600 640 deneysville
# city # 601 640 kalanguy
# city # 602 640 tianmen
# city # 603 640 yerofey pavlovich
# city # 604 640 vielsalm
# city # 605 640 sembakung
# city # 606 640 changtu
# city # 607 640 alyangula
# city # 608 640 zorritos
# city # 609 640 grand gaube
# city # 610 640 khandyga
# city # 611 640 okhotsk
# city # 612 640 jalu
# city # 613 640 cap malheureux
# city # 614 640 wenling
# city # 615 640 wewak
# city # 616 640 ternate
# city # 617 640 motala
# city # 618 640 umm jarr
# wrong city
# city # 619 640 usinsk
# city # 620 640 garchitorena
# city # 621 640 anan
# city # 622 640 ust-maya
# city # 623 640 gueret
# city # 624 640 nabire
# city # 625 640 visnes
# city # 626 640 svetlyy
# wrong city
# city # 627 640 zhob
# city # 628 640 syedove
# city # 629 640 kadnikov
# city # 630 640 pangnirtung
# city # 631 640 oleksandrivka
# city # 632 640 kununurra
# city # 633 640 sfantu gheorghe
# city # 634 640 hannibal
# city # 635 640 alirajpur
# city # 636 640 kasongo
# city # 637 640 mnogovershinnyy
# city # 638 640 galle
# city # 639 640 dandong
# city # 640 640 huntington

# %%
final_DF.head()
# Out:
#              temp    Lat    Long  humidity  Cloud Cover  Wind Speed
# City
# Pedernales  23.51   0.07  -80.05        89            6        1.99
# Kapaa       26.48  22.08 -159.32        69           75        8.20
# Macenta     17.54   8.55   -9.47        34           46        0.90
# Enugu       26.00   6.45    7.50        61           96        2.10
# Sterling     5.96  39.00  -77.40        41            1        3.60

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(figsize = (10, 5))
plt.scatter(x = final_DF['Lat'], y = final_DF['temp'])
plt.grid(True)
plt.title('Tempeture by Latitude', fontsize = 16)
plt.xlabel('Latitude', fontsize = 12)
plt.ylabel('temp', fontsize = 12)
plt.savefig('Temp.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(figsize = (10, 5))
plt.scatter(x = final_DF['Lat'], y = final_DF['humidity'])
plt.grid(True)
plt.title('Humidity by Latitude', fontsize = 16)
plt.xlabel('Latitude', fontsize = 12)
plt.ylabel('humidity', fontsize = 12)
plt.savefig('humid.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plot by windspeed
plt.figure(figsize = (10, 5))
plt.scatter(x = final_DF['Lat'], y = final_DF['Cloud Cover'])
plt.grid(True)
plt.title('Cloud Cover by Latitude', fontsize = 16)
plt.xlabel('Latitude', fontsize = 12)
plt.ylabel('Cloud Cover', fontsize = 12)

plt.savefig('Clouds.png')

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Plot by windspeed
plt.figure(figsize = (10, 5))
plt.scatter(x = final_DF['Lat'], y = final_DF['Wind Speed'])
plt.grid(True)
plt.title('Wind Speed by Latitude', fontsize = 16)
plt.xlabel('Latitude', fontsize = 12)
plt.ylabel('Wind Speed', fontsize = 12)
plt.savefig('Wind.png')

plt.show()

# %%
final_DF.to_csv(r'C:\Users\samms\Desktop\python_API_challenge\Instructions\starter_code\cities_output_file.csv')
